# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind309/Tensorflow-AI/blob/master/ANN_HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
model = Sequential()
model.add(Dense(units = 1))
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 551ms/step - loss: 3.4196
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8505
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3996
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0415
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7567
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5295
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3478
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2018
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0840
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9886
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9107
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8466
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.985]]
